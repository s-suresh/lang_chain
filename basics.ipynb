# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-0/basics.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/56295530-getting-set-up-video-guide)

# %% [markdown]
# # LangChain Academy
#
# Welcome to LangChain Academy!
#
# ## Context
#
# At LangChain, we aim to make it easy to build LLM applications. One type of LLM application you can build is an agent. There’s a lot of excitement around building agents because they can automate a wide range of tasks that were previously impossible.
#
# In practice though, it is incredibly difficult to build systems that reliably execute on these tasks. As we’ve worked with our users to put agents into production, we’ve learned that more control is often necessary. You might need an agent to always call a specific tool first or use different prompts based on its state.
#
# To tackle this problem, we’ve built [LangGraph](https://langchain-ai.github.io/langgraph/) — a framework for building agent and multi-agent applications. Separate from the LangChain package, LangGraph’s core design philosophy is to help developers add better precision and control into agent workflows, suitable for the complexity of real-world systems.
#
# ## Course Structure
#
# The course is structured as a set of modules, with each module focused on a particular theme related to LangGraph. You will see a folder for each module, which contains a series of notebooks. A video will accompany each notebook to help walk through the concepts, but the notebooks are also stand-alone, meaning that they contain explanations and can be viewed independently of the videos. Each module folder also contains a `studio` folder, which contains a set of graphs that can be loaded into [LangGraph Studio](https://github.com/langchain-ai/langgraph-studio), our IDE for building LangGraph applications.
#
# ## Setup
#
# Before you begin, please follow the instructions in the `README` to create an environment and install dependencies.
#
# ## Chat models
#
# In this course, we'll be using [Chat Models](https://python.langchain.com/v0.2/docs/concepts/#chat-models), which do a few things take a sequence of messages as inputs and return chat messages as outputs. LangChain does not host any Chat Models, rather we rely on third party integrations. [Here](https://python.langchain.com/v0.2/docs/integrations/chat/) is a list of 3rd party chat model integrations within LangChain! By default, the course will use [ChatOpenAI](https://python.langchain.com/v0.2/docs/integrations/chat/openai/) because it is both popular and performant. As noted, please ensure that you have an `OPENAI_API_KEY`.
#
# Let's check that your `OPENAI_API_KEY` is set and, if not, you will be asked to enter it.

# %%
import sys
print(sys.executable)

# !pip install cohere langchain_core langchain_community tavily-python
# !pip install langchain-community
# Out:
# /Library/anaconda3/envs/langchain-env/bin/python
# Requirement already satisfied: cohere in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (5.17.0)
# Requirement already satisfied: langchain_core in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (0.3.74)
# Requirement already satisfied: langchain_community in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (0.3.27)
# Requirement already satisfied: tavily-python in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (0.7.11)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (1.12.0)
# Requirement already satisfied: httpx>=0.21.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (0.4.0)
# Requirement already satisfied: pydantic>=1.9.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (2.11.7)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (2.33.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (2.32.5)
# Requirement already satisfied: tokenizers<1,>=0.15 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (0.21.4)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (2.32.4.20250809)
# Requirement already satisfied: typing_extensions>=4.0.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from cohere) (4.14.1)
# Requirement already satisfied: langsmith>=0.3.45 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_core) (0.4.14)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_core) (25.0)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_community) (2.0.43)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: numpy>=1.26.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain_community) (2.3.2)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from tavily-python) (0.11.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: anyio in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpx>=0.21.2->cohere) (4.10.0)
# Requirement already satisfied: certifi in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpx>=0.21.2->cohere) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpx>=0.21.2->cohere) (1.0.9)
# Requirement already satisfied: idna in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.9)
# Requirement already satisfied: orjson>=3.9.14 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain_core) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain_core) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic>=1.9.2->cohere) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->cohere) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from tiktoken>=0.5.1->tavily-python) (2025.7.34)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from tokenizers<1,>=0.15->cohere) (0.34.4)
# Requirement already satisfied: filelock in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2025.7.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (1.1.8)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from anyio->httpx>=0.21.2->cohere) (1.3.1)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: langchain-community in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (0.3.74)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: langsmith>=0.1.125 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (0.4.14)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain-community) (0.24.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.4)
# Requirement already satisfied: anyio in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sushma/langchain-academy/lc-academy-env/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("COHERE_API_KEY")
# Out:
# COHERE_API_KEY: ········

# %%
import sys
print(sys.executable)
# !{sys.executable} -m pip install -U langchain langchain-community
# Out:
# /Library/anaconda3/envs/langchain-env/bin/python
# Requirement already satisfied: langchain in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (0.3.27)
# Requirement already satisfied: langchain-community in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (0.3.74)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (0.4.15)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: anyio in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Library/anaconda3/envs/langchain-env/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)

# %% [markdown]
# [Here](https://python.langchain.com/v0.2/docs/how_to/#chat-models) is a useful how-to for all the things that you can do with chat models, but we'll show a few highlights below. If you've run `pip install -r requirements.txt` as noted in the README, then you've installed the `cohere` package. With this, we can instantiate our `cohere` model object. If you are signing up for the API for the first time, you should receive [free credits](https://community.openai.com/t/understanding-api-limits-and-free-tier/498517) that can be applied to any of the models. You can see pricing for various models [here](https://openai.com/api/pricing/). The notebooks will default to `gpt-4o` because it's a good balance of quality, price, and speed [see more here](https://help.openai.com/en/articles/7102672-how-can-i-access-gpt-4-gpt-4-turbo-gpt-4o-and-gpt-4o-mini), but you can also opt for the lower priced `gpt-3.5` series models.
#
# There are [a few standard parameters](https://python.langchain.com/v0.2/docs/concepts/#chat-models) that we can set with chat models. Two of the most common are:
#
# * `model`: the name of the model
# * `temperature`: the sampling temperature
#
# `Temperature` controls the randomness or creativity of the model's output where low temperature (close to 0) is more deterministic and focused outputs. This is good for tasks requiring accuracy or factual responses. High temperature (close to 1) is good for creative tasks or generating varied responses.

# %%
from langchain_community.llms import Cohere
llm = Cohere(model="command", temperature=0.0)

# %%
# !{sys.executable} -m pip install -U langchain-cohere
# Out:
# Collecting langchain-cohere
#   Using cached langchain_cohere-0.2.4-py3-none-any.whl (43 kB)
# Collecting cohere<6.0,>=5.5.6
#   Using cached cohere-5.13.2-py3-none-any.whl (249 kB)
# Collecting tabulate<0.10.0,>=0.9.0
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: langchain-core<0.3,>=0.2.33 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-cohere) (0.2.43)
# Collecting langchain-experimental>=0.0.6
#   Using cached langchain_experimental-0.0.65-py3-none-any.whl (207 kB)
# Requirement already satisfied: pandas>=1.4.3 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-cohere) (2.0.3)
# Collecting httpx-sse==0.4.0
#   Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: httpx>=0.21.2 in /Library/anaconda3/lib/python3.8/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere) (0.28.1)
# Collecting tokenizers<1,>=0.15
#   Using cached tokenizers-0.21.0.tar.gz (343 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/anaconda3/bin/python /Library/anaconda3/lib/python3.8/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-2jcb2dcw/normal --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- puccinialin
#        cwd: None
#   Complete output (2 lines):
#   ERROR: Could not find a version that satisfies the requirement puccinialin
#   ERROR: No matching distribution found for puccinialin
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/20/41/c2be10975ca37f6ec40d7abd7e98a5213bb04f284b869c1a24e6504fd94d/tokenizers-0.21.0.tar.gz#sha256=ee0894bf311b75b0c03079f33859ae4b2334d675d4e93f5a4132e1eae2834fe4 (from https://pypi.org/simple/tokenizers/) (requires-python:>=3.7). Command errored out with exit status 1: /Library/anaconda3/bin/python /Library/anaconda3/lib/python3.8/site-packages/pip install --ignore-installed --no-user --prefix /private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-2jcb2dcw/normal --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- puccinialin Check the logs for full command output.
#   Using cached tokenizers-0.20.3-cp38-cp38-macosx_10_12_x86_64.whl (2.7 MB)
# Collecting parameterized<0.10.0,>=0.9.0
#   Using cached parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Library/anaconda3/lib/python3.8/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere) (2.32.3)
# Requirement already satisfied: typing_extensions>=4.0.0 in /Library/anaconda3/lib/python3.8/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere) (4.12.2)
# Collecting types-requests<3.0.0,>=2.0.0
#   Using cached types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Collecting fastavro<2.0.0,>=1.9.4
#   Using cached fastavro-1.9.7.tar.gz (987 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Library/anaconda3/lib/python3.8/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere) (2.27.2)
# Requirement already satisfied: pydantic>=1.9.2 in /Library/anaconda3/lib/python3.8/site-packages (from cohere<6.0,>=5.5.6->langchain-cohere) (2.10.6)
# Requirement already satisfied: httpcore==1.* in /Library/anaconda3/lib/python3.8/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.5.6->langchain-cohere) (1.0.9)
# Requirement already satisfied: idna in /Library/anaconda3/lib/python3.8/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.5.6->langchain-cohere) (2.10)
# Requirement already satisfied: certifi in /Library/anaconda3/lib/python3.8/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.5.6->langchain-cohere) (2024.8.30)
# Requirement already satisfied: anyio in /Library/anaconda3/lib/python3.8/site-packages (from httpx>=0.21.2->cohere<6.0,>=5.5.6->langchain-cohere) (2.2.0)
# Requirement already satisfied: h11>=0.16 in /Library/anaconda3/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.5.6->langchain-cohere) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-core<0.3,>=0.2.33->langchain-cohere) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-core<0.3,>=0.2.33->langchain-cohere) (5.4.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.112 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-core<0.3,>=0.2.33->langchain-cohere) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-core<0.3,>=0.2.33->langchain-cohere) (8.3.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-core<0.3,>=0.2.33->langchain-cohere) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/anaconda3/lib/python3.8/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.33->langchain-cohere) (3.0.0)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.16 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-experimental>=0.0.6->langchain-cohere) (0.2.19)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (1.4.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.17 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (0.2.17)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (0.6.7)
# Requirement already satisfied: numpy<2,>=1 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (1.22.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Library/anaconda3/lib/python3.8/site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (3.10.11)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (2.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/anaconda3/lib/python3.8/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (6.1.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Library/anaconda3/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/anaconda3/lib/python3.8/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (3.22.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Library/anaconda3/lib/python3.8/site-packages (from langchain<0.3.0,>=0.2.17->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (0.2.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Library/anaconda3/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.33->langchain-cohere) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Library/anaconda3/lib/python3.8/site-packages (from langsmith<0.2.0,>=0.1.112->langchain-core<0.3,>=0.2.33->langchain-cohere) (3.10.15)
# Requirement already satisfied: tzdata>=2022.1 in /Library/anaconda3/lib/python3.8/site-packages (from pandas>=1.4.3->langchain-cohere) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Library/anaconda3/lib/python3.8/site-packages (from pandas>=1.4.3->langchain-cohere) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/anaconda3/lib/python3.8/site-packages (from pandas>=1.4.3->langchain-cohere) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/anaconda3/lib/python3.8/site-packages (from pydantic>=1.9.2->cohere<6.0,>=5.5.6->langchain-cohere) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Library/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.3->langchain-cohere) (1.15.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.5.6->langchain-cohere) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.5.6->langchain-cohere) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Library/anaconda3/lib/python3.8/site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (1.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Library/anaconda3/lib/python3.8/site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.5.6->langchain-cohere) (0.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Library/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.5.6->langchain-cohere) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Library/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.5.6->langchain-cohere) (1.1.2)
# Requirement already satisfied: filelock in /Library/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.5.6->langchain-cohere) (3.0.12)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/anaconda3/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.5.6->langchain-cohere) (2024.9.0)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/anaconda3/lib/python3.8/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (0.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Library/anaconda3/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental>=0.0.6->langchain-cohere) (0.2.0)
# Requirement already satisfied: sniffio>=1.1 in /Library/anaconda3/lib/python3.8/site-packages (from anyio->httpx>=0.21.2->cohere<6.0,>=5.5.6->langchain-cohere) (1.3.1)
# Building wheels for collected packages: fastavro
#   Building wheel for fastavro (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/anaconda3/bin/python /Library/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/tmp0pyy96us
#        cwd: /private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-install-1shd2m7u/fastavro_b8ebbf04ba624af0ac93f1ff2fe85a46
#   Complete output (540 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_schema_common.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_schema_py.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_logical_writers_py.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/json_read.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/write.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_write_common.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_write_py.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_read_py.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/types.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/json_write.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_read_common.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_validate_common.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_logical_readers_py.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/utils.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/logical_writers.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_validation_py.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/__main__.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/logical_readers.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/const.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/schema.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/read.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/validation.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   creating build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/binary_decoder.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/binary_encoder.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/parser.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/symbols.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/json_encoder.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   copying fastavro/io/json_decoder.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/io
#   creating build/lib.macosx-10.9-x86_64-cpython-38/fastavro/repository
#   copying fastavro/repository/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/repository
#   copying fastavro/repository/flat_dict.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/repository
#   copying fastavro/repository/base.py -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro/repository
#   copying fastavro/_logical_readers.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_logical_writers.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_logical_writers_py.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_read.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_validation.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_schema.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_write.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/_logical_readers_py.pyi -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   copying fastavro/py.typed -> build/lib.macosx-10.9-x86_64-cpython-38/fastavro
#   running build_ext
#   Compiling fastavro/_read.pyx because it changed.
#   [1/1] Cythonizing fastavro/_read.pyx
#   building 'fastavro._read' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-38/fastavro
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include/python3.8 -c fastavro/_read.c -o build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_read.o
#   fastavro/_read.c:24036:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    24036 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_read.c:24228:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    24228 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_read.c:24428:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    24428 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_read.c:24592:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    24592 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_read.c:30689:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    30689 |                 CYTHON_FALLTHROUGH;
#          |                 ^
#   fastavro/_read.c:511:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     511 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   fastavro/_read.c:30700:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    30700 |                 CYTHON_FALLTHROUGH;
#          |                 ^
#   fastavro/_read.c:511:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     511 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   6 warnings generated.
#   gcc -bundle -undefined dynamic_lookup -L/Library/anaconda3/lib -arch x86_64 -L/Library/anaconda3/lib -arch x86_64 build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_read.o -o build/lib.macosx-10.9-x86_64-cpython-38/fastavro/_read.cpython-38-darwin.so
#   Compiling fastavro/_schema.pyx because it changed.
#   [1/1] Cythonizing fastavro/_schema.pyx
#   building 'fastavro._schema' extension
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include/python3.8 -c fastavro/_schema.c -o build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_schema.o
#   fastavro/_schema.c:16960:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    16960 |                 CYTHON_FALLTHROUGH;
#          |                 ^
#   fastavro/_schema.c:512:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     512 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   fastavro/_schema.c:16971:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    16971 |                 CYTHON_FALLTHROUGH;
#          |                 ^
#   fastavro/_schema.c:512:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     512 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   fastavro/_schema.c:19374:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    19374 |                 CYTHON_FALLTHROUGH;
#          |                 ^
#   fastavro/_schema.c:512:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     512 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   fastavro/_schema.c:19385:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    19385 |                 CYTHON_FALLTHROUGH;
#          |                 ^
#   fastavro/_schema.c:512:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     512 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   4 warnings generated.
#   gcc -bundle -undefined dynamic_lookup -L/Library/anaconda3/lib -arch x86_64 -L/Library/anaconda3/lib -arch x86_64 build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_schema.o -o build/lib.macosx-10.9-x86_64-cpython-38/fastavro/_schema.cpython-38-darwin.so
#   Compiling fastavro/_write.pyx because it changed.
#   [1/1] Cythonizing fastavro/_write.pyx
#   building 'fastavro._write' extension
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include/python3.8 -c fastavro/_write.c -o build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_write.o
#   fastavro/_write.c:35249:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    35249 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:35664:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    35664 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:35813:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    35813 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:35973:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    35973 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:36133:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    36133 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:36306:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    36306 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:36546:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    36546 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:36711:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    36711 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:37030:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    37030 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   fastavro/_write.c:37196:3: warning: 'tp_print' is deprecated [-Wdeprecated-declarations]
#    37196 |   0, /*tp_print*/
#          |   ^
#   /Library/anaconda3/include/python3.8/cpython/object.h:260:5: note: 'tp_print' has been explicitly marked deprecated here
#     260 |     Py_DEPRECATED(3.8) int (*tp_print)(PyObject *, FILE *, int);
#         |     ^
#   /Library/anaconda3/include/python3.8/pyport.h:515:54: note: expanded from macro 'Py_DEPRECATED'
#     515 | #define Py_DEPRECATED(VERSION_UNUSED) __attribute__((__deprecated__))
#         |                                                      ^
#   10 warnings generated.
#   gcc -bundle -undefined dynamic_lookup -L/Library/anaconda3/lib -arch x86_64 -L/Library/anaconda3/lib -arch x86_64 build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_write.o -o build/lib.macosx-10.9-x86_64-cpython-38/fastavro/_write.cpython-38-darwin.so
#   Compiling fastavro/_validation.pyx because it changed.
#   [1/1] Cythonizing fastavro/_validation.pyx
#   building 'fastavro._validation' extension
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include/python3.8 -c fastavro/_validation.c -o build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_validation.o
#   gcc -bundle -undefined dynamic_lookup -L/Library/anaconda3/lib -arch x86_64 -L/Library/anaconda3/lib -arch x86_64 build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_validation.o -o build/lib.macosx-10.9-x86_64-cpython-38/fastavro/_validation.cpython-38-darwin.so
#   Compiling fastavro/_logical_readers.pyx because it changed.
#   [1/1] Cythonizing fastavro/_logical_readers.pyx
#   building 'fastavro._logical_readers' extension
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include -arch x86_64 -I/Library/anaconda3/include/python3.8 -c fastavro/_logical_readers.c -o build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_logical_readers.o
#   fastavro/_logical_readers.c:7718:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    7718 |                 CYTHON_FALLTHROUGH;
#         |                 ^
#   fastavro/_logical_readers.c:511:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     511 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   fastavro/_logical_readers.c:7729:17: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#    7729 |                 CYTHON_FALLTHROUGH;
#         |                 ^
#   fastavro/_logical_readers.c:511:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#     511 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#         |                                  ^
#   2 warnings generated.
#   gcc -bundle -undefined dynamic_lookup -L/Library/anaconda3/lib -arch x86_64 -L/Library/anaconda3/lib -arch x86_64 build/temp.macosx-10.9-x86_64-cpython-38/fastavro/_logical_readers.o -o build/lib.macosx-10.9-x86_64-cpython-38/fastavro/_logical_readers.cpython-38-darwin.so
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#   import decimal
#   import os
#   import uuid
#
#   from libc.time cimport tm, mktime
#   from cpython.int cimport PyInt_AS_LONG
#   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:10:0: 'cpython/int.pxd' not found
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#   import decimal
#   import os
#   import uuid
#
#   from libc.time cimport tm, mktime
#   from cpython.int cimport PyInt_AS_LONG
#   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:10:0: 'cpython/int/PyInt_AS_LONG.pxd' not found
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#                   (delta.days * 24 * 3600 + delta.seconds) * MLS_PER_SECOND
#                   + int(delta.microseconds / 1000)
#               )
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#                                   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:50:32: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#                   + int(delta.microseconds / 1000)
#               )
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#                                   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:51:32: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               )
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#                                    ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:52:33: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#                                    ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:53:33: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#               time_tuple.tm_mon = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 1))) - 1
#                                   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:54:32: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#               time_tuple.tm_mon = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 1))) - 1
#               time_tuple.tm_year = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 0))) - 1900
#                                    ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:55:33: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#               time_tuple.tm_mon = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 1))) - 1
#               time_tuple.tm_year = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 0))) - 1900
#               time_tuple.tm_isdst = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 8)))
#                                     ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:56:34: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#                   (delta.days * 24 * 3600 + delta.seconds) * MCS_PER_SECOND
#                   + delta.microseconds
#               )
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#                                   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:97:32: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#                   + delta.microseconds
#               )
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#                                   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:98:32: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               )
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#                                    ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:99:33: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#           else:
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#                                    ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:100:33: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               tt = data.timetuple()
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#               time_tuple.tm_mon = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 1))) - 1
#                                   ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:101:32: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               time_tuple.tm_sec = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 5)))
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#               time_tuple.tm_mon = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 1))) - 1
#               time_tuple.tm_year = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 0))) - 1900
#                                    ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:102:33: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#
#   Error compiling Cython file:
#   ------------------------------------------------------------
#   ...
#               time_tuple.tm_min = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 4)))
#               time_tuple.tm_hour = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 3)))
#               time_tuple.tm_mday = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 2)))
#               time_tuple.tm_mon = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 1))) - 1
#               time_tuple.tm_year = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 0))) - 1900
#               time_tuple.tm_isdst = PyInt_AS_LONG(<object>(PyTuple_GET_ITEM(tt, 8)))
#                                     ^
#   ------------------------------------------------------------
#
#   fastavro/_logical_writers.pyx:103:34: 'PyInt_AS_LONG' is not a constant, variable or function identifier
#   Compiling fastavro/_logical_writers.pyx because it changed.
#   [1/1] Cythonizing fastavro/_logical_writers.pyx
#   Traceback (most recent call last):
#     File "/Library/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py", line 280, in <module>
#       main()
#     File "/Library/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py", line 263, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "/Library/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py", line 204, in build_wheel
#       return _build_backend().build_wheel(wheel_directory, config_settings,
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/build_meta.py", line 437, in build_wheel
#       return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/build_meta.py", line 425, in _build
#       return self._build_with_temp_dir(
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/build_meta.py", line 406, in _build_with_temp_dir
#       self.run_setup()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/build_meta.py", line 319, in run_setup
#       exec(code, locals())
#     File "<string>", line 37, in <module>
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/__init__.py", line 117, in setup
#       return distutils.core.setup(**attrs)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/core.py", line 183, in setup
#       return run_commands(dist)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/core.py", line 199, in run_commands
#       dist.run_commands()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/dist.py", line 954, in run_commands
#       self.run_command(cmd)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/dist.py", line 999, in run_command
#       super().run_command(command)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/dist.py", line 973, in run_command
#       cmd_obj.run()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/command/bdist_wheel.py", line 400, in run
#       self.run_command("build")
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/cmd.py", line 316, in run_command
#       self.distribution.run_command(command)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/dist.py", line 999, in run_command
#       super().run_command(command)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/dist.py", line 973, in run_command
#       cmd_obj.run()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/cmd.py", line 316, in run_command
#       self.distribution.run_command(command)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/dist.py", line 999, in run_command
#       super().run_command(command)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/dist.py", line 973, in run_command
#       cmd_obj.run()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/command/build_ext.py", line 98, in run
#       _build_ext.run(self)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py", line 359, in run
#       self.build_extensions()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py", line 476, in build_extensions
#       self._build_extensions_serial()
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/_distutils/command/build_ext.py", line 502, in _build_extensions_serial
#       self.build_extension(ext)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/setuptools/command/build_ext.py", line 263, in build_extension
#       _build_ext.build_extension(self, ext)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/Cython/Distutils/build_ext.py", line 131, in build_extension
#       new_ext = cythonize(
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/Cython/Build/Dependencies.py", line 1154, in cythonize
#       cythonize_one(*args)
#     File "/private/var/folders/lb/fgpr2zc115s4kyxx4448v16w0000gn/T/pip-build-env-tp1z_9k6/overlay/lib/python3.8/site-packages/Cython/Build/Dependencies.py", line 1298, in cythonize_one
#       raise CompileError(None, pyx_file)
#   Cython.Compiler.Errors.CompileError: fastavro/_logical_writers.pyx
#   ----------------------------------------
#   ERROR: Failed building wheel for fastavro
# Failed to build fastavro
# ERROR: Could not build wheels for fastavro which use PEP 517 and cannot be installed directly

# %% [markdown]
# Chat models in LangChain have a number of [default methods](https://python.langchain.com/v0.2/docs/concepts/#runnable-interface). For the most part, we'll be using:
#
# * `stream`: stream back chunks of the response
# * `invoke`: call the chain on an input
#
# And, as mentioned, chat models take [messages](https://python.langchain.com/v0.2/docs/concepts/#messages) as input. Messages have a role (that describes who is saying the message) and a content property. We'll be talking a lot more about this later, but here let's just show the basics.

# %%
import sys
print(sys.executable)
# Out:
# /Library/anaconda3/envs/langchain-env/bin/python

# %%
from langchain_core.messages import HumanMessage

# Create a message
msg = HumanMessage(content="Hello what is my name?", name="Lance")

# Message list
messages = [msg]

# Invoke the model with a list of messages 
llm.invoke(messages)

# %% [markdown]
# We get an `AIMessage` response. Also, note that we can just invoke a chat model with a string. When a string is passed in as input, it is converted to a `HumanMessage` and then passed to the underlying model.

# %%
llm.invoke("hello world")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 9, 'total_tokens': 18}, 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5', 'finish_reason': 'stop', 'logprobs': None}, id='run-d6f6b682-e29a-44de-b45e-79fad1e405e5-0', usage_metadata={'input_tokens': 9, 'output_tokens': 9, 'total_tokens': 18})

# %% [markdown]
# The interface is consistent across all chat models and models are typically initialized once at the start up each notebooks.
#
# So, you can easily switch between models without changing the downstream code if you have strong preference for another provider.

# %% [markdown]
# ## Search Tools
#
# You'll also see [Tavily](https://tavily.com/) in the README, which is a search engine optimized for LLMs and RAG, aimed at efficient, quick, and persistent search results. As mentioned, it's easy to sign up and offers a generous free tier. Some lessons (in Module 4) will use Tavily by default but, of course, other search tools can be used if you want to modify the code for yourself.

# %%
_set_env("TAVILY_API_KEY")

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
tavily_search = TavilySearchResults(max_results=3)
search_docs = tavily_search.invoke("What is LangGraph?")

# %%
search_docs
